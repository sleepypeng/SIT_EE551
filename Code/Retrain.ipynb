# %%
###  we copy Retrain.ipynb from internet ,which is written by Radek Bartyzal.
###  What we did is retrain the new model and change some parameters
###  We write the loop ourselves.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import glob
import hashlib
import os.path
import random
import re
import sys
import tarfile
import os

import numpy as np
from six.moves import urllib
import tensorflow as tf

from tensorflow.python.framework import graph_util
from tensorflow.python.framework import tensor_shape
from tensorflow.python.platform import gfile
from tensorflow.python.util import compat
import struct

# %%
FLAGS = tf.app.flags.FLAGS

# Input and output file flags.
tf.app.flags.DEFINE_string('image_dir', 'images',
                           """Path to folders of labeled images.""")
tf.app.flags.DEFINE_string('output_graph', '/tmp/Final/output_graph.pb',
                           """Where to save the trained graph.""")
tf.app.flags.DEFINE_string('output_labels', '/tmp/Final/output_labels.txt',
                           """Where to save the trained graph's labels.""")
tf.app.flags.DEFINE_string('summaries_dir', '/tmp/Final/retrain_logs',
                          """Where to save summary logs for TensorBoard.""")

# Details of the training configuration.
tf.app.flags.DEFINE_integer('how_many_training_steps', 2000,
                            """How many training steps to run before ending.""")
tf.app.flags.DEFINE_float('learning_rate', 0.01,
                          """How large a learning rate to use when training.""")
tf.app.flags.DEFINE_integer(
    'testing_percentage', 2,
    """What percentage of images to use as a test set.""")
tf.app.flags.DEFINE_integer(
    'validation_percentage', 10,
    """What percentage of images to use as a validation set.""")
tf.app.flags.DEFINE_integer('eval_step_interval', 10,
                            """How often to evaluate the training results.""")
tf.app.flags.DEFINE_integer('train_batch_size', 16,
                            """How many images to train on at a time.""")
tf.app.flags.DEFINE_integer('test_batch_size',16,
                            """How many images to test on at a time. This"""
                            """ test set is only used infrequently to verify"""
                            """ the overall accuracy of the model.""")
tf.app.flags.DEFINE_integer(
    'validation_batch_size', 16,
    """How many images to use in an evaluation batch. This validation set is"""
    """ used much more often than the test set, and is an early indicator of"""
    """ how accurate the model is during training.""")

# File-system cache locations.
tf.app.flags.DEFINE_string('model_dir', '/tmp/Final/imagenet',
                           """Path to classify_image_graph_def.pb, """
                           """imagenet_synset_to_human_label_map.txt, and """
                           """imagenet_2012_challenge_label_map_proto.pbtxt.""")
tf.app.flags.DEFINE_string(
    'bottleneck_dir', '/tmp/Final/bottleneck',
    """Path to cache bottleneck layer values as files.""")
tf.app.flags.DEFINE_string('final_tensor_name', 'final_result',
                           """The name of the output classification layer in"""
                           """ the retrained graph.""")

# Controls the distortions used during training.
tf.app.flags.DEFINE_boolean(
    'flip_left_right', False,
    """Whether to randomly flip half of the training images horizontally.""")
tf.app.flags.DEFINE_integer(
    'random_crop', 0,
    """A percentage determining how much of a margin to randomly crop off the"""
    """ training images.""")
tf.app.flags.DEFINE_integer(
    'random_scale', 0,
    """A percentage determining how much to randomly scale up the size of the"""
    """ training images by.""")
tf.app.flags.DEFINE_integer(
    'random_brightness', 0,
    """A percentage determining how much to randomly multiply the training"""
    """ image input pixels up or down by.""")

# These are all parameters that are tied to the particular model architecture
# we're using for Inception v3. These include things like tensor names and their
# sizes. If you want to adapt this script to work with another model, you will
# need to update these to reflect the values in the network you're using.
# pylint: disable=line-too-long
DATA_URL = 'http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz'
# pylint: enable=line-too-long
BOTTLENECK_TENSOR_NAME = 'pool_3/_reshape:0'
BOTTLENECK_TENSOR_SIZE = 2048
MODEL_INPUT_WIDTH = 400
MODEL_INPUT_HEIGHT = 400
MODEL_INPUT_DEPTH = 3
JPEG_DATA_TENSOR_NAME = 'DecodeJpeg/contents:0'
RESIZED_INPUT_TENSOR_NAME = 'ResizeBilinear:0'
MAX_NUM_IMAGES_PER_CLASS = 2 ** 27 - 1  # ~134M

# Directory containing files with correct image labels for each image.
IMAGE_LABELS_DIR = '/Users/liutianchen/Desktop/CPE646-Finalprject/Code/image_labels_dir'
# Contains cached ground_truth vectors to prevent calculating them again and again
CACHED_GROUND_TRUTH_VECTORS = {}
# Contains list of all labels, each label is on a separate line, just like in image_label files
ALL_LABELS_FILE = "/Users/liutianchen/Desktop/CPE646-Finalprject/Code/labels.txt"


def create_image_lists(image_dir, testing_percentage, validation_percentage):
  """Builds a list of training images from the file system.

  Analyzes the sub folders in the image directory, splits them into stable
  training, testing, and validation sets, and returns a data structure
  describing the lists of images for each label and their paths.

  Args:
    image_dir: String path to a folder containing subfolders of images.
    testing_percentage: Integer percentage of the images to reserve for tests.
    validation_percentage: Integer percentage of images reserved for validation.

  Returns:
    A dictionary containing an entry for each label subfolder, with images split
    into training, testing, and validation sets within each label.
  """
  if not gfile.Exists(image_dir):
    print("Image directory '" + image_dir + "' not found.")
    return None
  result = {}
  sub_dirs = [x[0] for x in os.walk(image_dir)]
  # The root directory comes first, so skip it.
  is_root_dir = True
  for sub_dir in sub_dirs:
    if is_root_dir:
      is_root_dir = False
      continue
    extensions = ['jpg', 'jpeg', 'JPG', 'JPEG']
    file_list = []
    dir_name = os.path.basename(sub_dir)
    if dir_name == image_dir:
      continue
    print("Looking for images in '" + dir_name + "'")
    for extension in extensions:
      file_glob = os.path.join(image_dir, dir_name, '*.' + extension)
      file_list.extend(glob.glob(file_glob))
    if not file_list:
      print('No files found')
      continue
    if len(file_list) < 20:
      print('WARNING: Folder has less than 20 images, which may cause issues.')
    elif len(file_list) > MAX_NUM_IMAGES_PER_CLASS:
      print('WARNING: Folder {} has more than {} images. Some images will '
            'never be selected.'.format(dir_name, MAX_NUM_IMAGES_PER_CLASS))
    label_name = re.sub(r'[^a-z0-9]+', ' ', dir_name.lower())
    training_images = []
    testing_images = []
    validation_images = []
    for file_name in file_list:
      base_name = os.path.basename(file_name)
      # We want to ignore anything after '_nohash_' in the file name when
      # deciding which set to put an image in, the data set creator has a way of
      # grouping photos that are close variations of each other. For example
      # this is used in the plant disease data set to group multiple pictures of
      # the same leaf.
      hash_name = re.sub(r'_nohash_.*$', '', file_name)
      # This looks a bit magical, but we need to decide whether this file should
      # go into the training, testing, or validation sets, and we want to keep
      # existing files in the same set even if more files are subsequently
      # added.
      # To do that, we need a stable way of deciding based on just the file name
      # itself, so we do a hash of that and then use that to generate a
      # probability value that we use to assign it.
      hash_name_hashed = hashlib.sha1(compat.as_bytes(hash_name)).hexdigest()
      percentage_hash = ((int(hash_name_hashed, 16) %
                          (MAX_NUM_IMAGES_PER_CLASS + 1)) *
                         (100.0 / MAX_NUM_IMAGES_PER_CLASS))
      if percentage_hash < validation_percentage:
        validation_images.append(base_name)
      elif percentage_hash < (testing_percentage + validation_percentage):
        testing_images.append(base_name)
      else:
        training_images.append(base_name)
    result[label_name] = {
        'dir': dir_name,
        'training': training_images,
        'testing': testing_images,
        'validation': validation_images,
    }
  return result

def get_image_labels_path(image_lists, label_name, index, image_labels_dir, category):
  """"Returns a path to a file containing correct image labels.

  This is just slightly edited get_image_path() method.

  Args:
    image_lists: Dictionary of training images for each label.
    label_name: Label string we want to get an image for.
    index: Int offset of the image we want. This will be moduloed by the
    available number of images for the label, so it can be arbitrarily large.
    image_labels_dir: Root folder string of the subfolders containing the training
    images.
    category: Name string of set to pull images from - training, testing, or
    validation.

  Returns:
    File system path string to an image that meets the requested parameters.

  """
  if label_name not in image_lists:
    tf.logging.fatal('Label does not exist %s.', label_name)
  label_lists = image_lists[label_name]
  if category not in label_lists:
    tf.logging.fatal('Category does not exist %s.', category)
  category_list = label_lists[category]
  if not category_list:
    tf.logging.fatal('Label %s has no images in the category %s.',
                     label_name, category)
  mod_index = index % len(category_list)
  base_name = category_list[mod_index]
  full_path = os.path.join(image_labels_dir, base_name)
  full_path += '.txt'
  return full_path

def get_image_path(image_lists, label_name, index, image_dir, category):
  """"Returns a path to an image for a label at the given index.

  Args:
    image_lists: Dictionary of training images for each label.
    label_name: Label string we want to get an image for.
    index: Int offset of the image we want. This will be moduloed by the
    available number of images for the label, so it can be arbitrarily large.
    image_dir: Root folder string of the subfolders containing the training
    images.
    category: Name string of set to pull images from - training, testing, or
    validation.

  Returns:
    File system path string to an image that meets the requested parameters.

  """
  if label_name not in image_lists:
    tf.logging.fatal('Label does not exist %s.', label_name)
  label_lists = image_lists[label_name]
  if category not in label_lists:
    tf.logging.fatal('Category does not exist %s.', category)
  category_list = label_lists[category]
  if not category_list:
    tf.logging.fatal('Label %s has no images in the category %s.',
                     label_name, category)
  mod_index = index % len(category_list)
  base_name = category_list[mod_index]
  sub_dir = label_lists['dir']
  full_path = os.path.join(image_dir, sub_dir, base_name)
  return full_path


def get_bottleneck_path(image_lists, label_name, index, bottleneck_dir,
                        category):
  """"Returns a path to a bottleneck file for a label at the given index.

  Args:
    image_lists: Dictionary of training images for each label.
    label_name: Label string we want to get an image for.
    index: Integer offset of the image we want. This will be moduloed by the
    available number of images for the label, so it can be arbitrarily large.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    category: Name string of set to pull images from - training, testing, or
    validation.

  Returns:
    File system path string to an image that meets the requested parameters.
  """
  return get_image_path(image_lists, label_name, index, bottleneck_dir,
                        category) + '.txt'


def create_inception_graph():
  """"Creates a graph from saved GraphDef file and returns a Graph object.

  Returns:
    Graph holding the trained Inception network, and various tensors we'll be
    manipulating.
  """
  with tf.Session() as sess:
    model_filename = os.path.join(
        FLAGS.model_dir, 'classify_image_graph_def.pb')
    with gfile.FastGFile(model_filename, 'rb') as f:
      graph_def = tf.GraphDef()
      graph_def.ParseFromString(f.read())
      bottleneck_tensor, jpeg_data_tensor, resized_input_tensor = (
          tf.import_graph_def(graph_def, name='', return_elements=[
              BOTTLENECK_TENSOR_NAME, JPEG_DATA_TENSOR_NAME,
              RESIZED_INPUT_TENSOR_NAME]))
  return sess.graph, bottleneck_tensor, jpeg_data_tensor, resized_input_tensor


def run_bottleneck_on_image(sess, image_data, image_data_tensor,
                            bottleneck_tensor):
  """Runs inference on an image to extract the 'bottleneck' summary layer.

  Args:
    sess: Current active TensorFlow Session.
    image_data: String of raw JPEG data.
    image_data_tensor: Input data layer in the graph.
    bottleneck_tensor: Layer before the final softmax.

  Returns:
    Numpy array of bottleneck values.
  """
  bottleneck_values = sess.run(
      bottleneck_tensor,
      {image_data_tensor: image_data})
  bottleneck_values = np.squeeze(bottleneck_values)
  return bottleneck_values


def maybe_download_and_extract():
  """Download and extract model tar file.

  If the pretrained model we're using doesn't already exist, this function
  downloads it from the TensorFlow.org website and unpacks it into a directory.
  """
  dest_directory = FLAGS.model_dir
  if not os.path.exists(dest_directory):
    os.makedirs(dest_directory)
  filename = DATA_URL.split('/')[-1]
  filepath = os.path.join(dest_directory, filename)
  if not os.path.exists(filepath):

    def _progress(count, block_size, total_size):
      sys.stdout.write('\r>> Downloading %s %.1f%%' %
                       (filename,
                        float(count * block_size) / float(total_size) * 100.0))
      sys.stdout.flush()

    filepath, _ = urllib.request.urlretrieve(DATA_URL,
                                             filepath,
                                             _progress)
    print()
    statinfo = os.stat(filepath)
    print('Successfully downloaded', filename, statinfo.st_size, 'bytes.')
  tarfile.open(filepath, 'r:gz').extractall(dest_directory)


def ensure_dir_exists(dir_name):
  """Makes sure the folder exists on disk.

  Args:
    dir_name: Path string to the folder we want to create.
  """
  if not os.path.exists(dir_name):
    os.makedirs(dir_name)


def write_list_of_floats_to_file(list_of_floats , file_path):
  """Writes a given list of floats to a binary file.

  Args:
    list_of_floats: List of floats we want to write to a file.
    file_path: Path to a file where list of floats will be stored.

  """

  s = struct.pack('d' * BOTTLENECK_TENSOR_SIZE, *list_of_floats)
  with open(file_path, 'wb') as f:
    f.write(s)


def read_list_of_floats_from_file(file_path):
  """Reads list of floats from a given file.

  Args:
    file_path: Path to a file where list of floats was stored.
  Returns:
    Array of bottleneck values (list of floats).

  """

  with open(file_path, 'rb') as f:
    s = struct.unpack('d' * BOTTLENECK_TENSOR_SIZE, f.read())
    return list(s)


bottleneck_path_2_bottleneck_values = {}


def get_or_create_bottleneck(sess, image_lists, label_name, index, image_dir,
                             category, bottleneck_dir, jpeg_data_tensor,
                             bottleneck_tensor):
  """Retrieves or calculates bottleneck values for an image.

  If a cached version of the bottleneck data exists on-disk, return that,
  otherwise calculate the data and save it to disk for future use.

  Args:
    sess: The current active TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    label_name: Label string we want to get an image for.
    index: Integer offset of the image we want. This will be modulo-ed by the
    available number of images for the label, so it can be arbitrarily large.
    image_dir: Root folder string  of the subfolders containing the training
    images.
    category: Name string of which  set to pull images from - training, testing,
    or validation.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    jpeg_data_tensor: The tensor to feed loaded jpeg data into.
    bottleneck_tensor: The output tensor for the bottleneck values.

  Returns:
    Numpy array of values produced by the bottleneck layer for the image.
  """
  label_lists = image_lists[label_name]
  sub_dir = label_lists['dir']
  sub_dir_path = os.path.join(bottleneck_dir, sub_dir)
  ensure_dir_exists(sub_dir_path)
  bottleneck_path = get_bottleneck_path(image_lists, label_name, index,
                                        bottleneck_dir, category)
  if not os.path.exists(bottleneck_path):
    print('Creating bottleneck at ' + bottleneck_path)
    image_path = get_image_path(image_lists, label_name, index, image_dir,
                                category)
    if not gfile.Exists(image_path):
      tf.logging.fatal('File does not exist %s', image_path)
    image_data = gfile.FastGFile(image_path, 'rb').read()
    bottleneck_values = run_bottleneck_on_image(sess, image_data,
                                                jpeg_data_tensor,
                                                bottleneck_tensor)
    bottleneck_string = ','.join(str(x) for x in bottleneck_values)
    with open(bottleneck_path, 'w') as bottleneck_file:
      bottleneck_file.write(bottleneck_string)

  with open(bottleneck_path, 'r') as bottleneck_file:
    bottleneck_string = bottleneck_file.read()
  bottleneck_values = [float(x) for x in bottleneck_string.split(',')]
  return bottleneck_values


def cache_bottlenecks(sess, image_lists, image_dir, bottleneck_dir,
                      jpeg_data_tensor, bottleneck_tensor):
  """Ensures all the training, testing, and validation bottlenecks are cached.

  Because we're likely to read the same image multiple times (if there are no
  distortions applied during training) it can speed things up a lot if we
  calculate the bottleneck layer values once for each image during
  preprocessing, and then just read those cached values repeatedly during
  training. Here we go through all the images we've found, calculate those
  values, and save them off.

  Args:
    sess: The current active TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    image_dir: Root folder string of the subfolders containing the training
    images.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    jpeg_data_tensor: Input tensor for jpeg data from file.
    bottleneck_tensor: The penultimate output layer of the graph.

  Returns:
    Nothing.
  """
  how_many_bottlenecks = 0
  ensure_dir_exists(bottleneck_dir)
  for label_name, label_lists in image_lists.items():
    for category in ['training', 'testing', 'validation']:
      category_list = label_lists[category]
      for index, unused_base_name in enumerate(category_list):
        get_or_create_bottleneck(sess, image_lists, label_name, index,
                                 image_dir, category, bottleneck_dir,
                                 jpeg_data_tensor, bottleneck_tensor)
        how_many_bottlenecks += 1
        if how_many_bottlenecks % 100 == 0:
          print(str(how_many_bottlenecks) + ' bottleneck files created.')

def get_ground_truth(labels_file, labels, class_count):
    if labels_file in CACHED_GROUND_TRUTH_VECTORS.keys():
        ground_truth = CACHED_GROUND_TRUTH_VECTORS[labels_file]
    else:
        with open(labels_file) as f:
            true_labels = f.read().splitlines()
        ground_truth = np.zeros(class_count, dtype=np.float32)

        idx = 0
        for label in labels:
            if label in true_labels:
                ground_truth[idx] = 1.0
            idx += 1
        CACHED_GROUND_TRUTH_VECTORS[labels_file] = ground_truth

    return ground_truth

def get_random_cached_bottlenecks(sess, image_lists, how_many, category,
                                  bottleneck_dir, image_dir, jpeg_data_tensor,
                                  bottleneck_tensor, labels):
  """Retrieves bottleneck values for cached images.

  If no distortions are being applied, this function can retrieve the cached
  bottleneck values directly from disk for images. It picks a random set of
  images from the specified category.

  Args:
    sess: Current TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    how_many: The number of bottleneck values to return.
    category: Name string of which set to pull from - training, testing, or
    validation.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    image_dir: Root folder string of the subfolders containing the training
    images.
    jpeg_data_tensor: The layer to feed jpeg image data into.
    bottleneck_tensor: The bottleneck output layer of the CNN graph.
    labels: All possible labels loaded from file labels.txt.

  Returns:
    List of bottleneck arrays and their corresponding ground truths.
  """
  # class_count = len(image_lists.keys())
  class_count = len(labels)
  bottlenecks = []
  ground_truths = []
  for unused_i in range(how_many):
    # label_index = random.randrange(class_count)
    label_index = 0 # there is only one folder with images = 'multi-label'
    label_name = list(image_lists.keys())[label_index]
    image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
    bottleneck = get_or_create_bottleneck(sess, image_lists, label_name,
                                          image_index, image_dir, category,
                                          bottleneck_dir, jpeg_data_tensor,
                                          bottleneck_tensor)

    labels_file = get_image_labels_path(image_lists, label_name, image_index, IMAGE_LABELS_DIR, category)
    ground_truth = get_ground_truth(labels_file, labels, class_count)

    bottlenecks.append(bottleneck)
    ground_truths.append(ground_truth)
  return bottlenecks, ground_truths


def get_random_distorted_bottlenecks(
    sess, image_lists, how_many, category, image_dir, input_jpeg_tensor,
    distorted_image, resized_input_tensor, bottleneck_tensor, labels):
  """Retrieves bottleneck values for training images, after distortions.

  If we're training with distortions like crops, scales, or flips, we have to
  recalculate the full model for every image, and so we can't use cached
  bottleneck values. Instead we find random images for the requested category,
  run them through the distortion graph, and then the full graph to get the
  bottleneck results for each.

  Args:
    sess: Current TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    how_many: The integer number of bottleneck values to return.
    category: Name string of which set of images to fetch - training, testing,
    or validation.
    image_dir: Root folder string of the subfolders containing the training
    images.
    input_jpeg_tensor: The input layer we feed the image data to.
    distorted_image: The output node of the distortion graph.
    resized_input_tensor: The input node of the recognition graph.
    bottleneck_tensor: The bottleneck output layer of the CNN graph.
    labels: All possible labels loaded from file labels.txt.

  Returns:
    List of bottleneck arrays and their corresponding ground truths.
  """
  class_count = len(labels)
  bottlenecks = []
  ground_truths = []
  for unused_i in range(how_many):
    label_index = 0 # there is only one folder with images = 'multi-label'
    label_name = list(image_lists.keys())[label_index]
    image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
    image_path = get_image_path(image_lists, label_name, image_index, image_dir,
                                category)
    if not gfile.Exists(image_path):
      tf.logging.fatal('File does not exist %s', image_path)
    jpeg_data = gfile.FastGFile(image_path, 'rb').read()
    # Note that we materialize the distorted_image_data as a numpy array before
    # sending running inference on the image. This involves 2 memory copies and
    # might be optimized in other implementations.
    distorted_image_data = sess.run(distorted_image,
                                    {input_jpeg_tensor: jpeg_data})
    bottleneck = run_bottleneck_on_image(sess, distorted_image_data,
                                         resized_input_tensor,
                                         bottleneck_tensor)

    labels_file = get_image_labels_path(image_lists, label_name, image_index, IMAGE_LABELS_DIR, category)
    ground_truth = get_ground_truth(labels_file, labels, class_count)

    bottlenecks.append(bottleneck)
    ground_truths.append(ground_truth)
  return bottlenecks, ground_truths


def should_distort_images(flip_left_right, random_crop, random_scale,
                          random_brightness):
  """Whether any distortions are enabled, from the input flags.

  Args:
    flip_left_right: Boolean whether to randomly mirror images horizontally.
    random_crop: Integer percentage setting the total margin used around the
    crop box.
    random_scale: Integer percentage of how much to vary the scale by.
    random_brightness: Integer range to randomly multiply the pixel values by.

  Returns:
    Boolean value indicating whether any distortions should be applied.
  """
  return (flip_left_right or (random_crop != 0) or (random_scale != 0) or
          (random_brightness != 0))


def add_input_distortions(flip_left_right, random_crop, random_scale,
                          random_brightness):
  """Creates the operations to apply the specified distortions.

  During training it can help to improve the results if we run the images
  through simple distortions like crops, scales, and flips. These reflect the
  kind of variations we expect in the real world, and so can help train the
  model to cope with natural data more effectively. Here we take the supplied
  parameters and construct a network of operations to apply them to an image.

  Cropping
  ~~~~~~~~

  Cropping is done by placing a bounding box at a random position in the full
  image. The cropping parameter controls the size of that box relative to the
  input image. If it's zero, then the box is the same size as the input and no
  cropping is performed. If the value is 50%, then the crop box will be half the
  width and height of the input. In a diagram it looks like this:

  <       width         >
  +---------------------+
  |                     |
  |   width - crop%     |
  |    <      >         |
  |    +------+         |
  |    |      |         |
  |    |      |         |
  |    |      |         |
  |    +------+         |
  |                     |
  |                     |
  +---------------------+

  Scaling
  ~~~~~~~

  Scaling is a lot like cropping, except that the bounding box is always
  centered and its size varies randomly within the given range. For example if
  the scale percentage is zero, then the bounding box is the same size as the
  input and no scaling is applied. If it's 50%, then the bounding box will be in
  a random range between half the width and height and full size.

  Args:
    flip_left_right: Boolean whether to randomly mirror images horizontally.
    random_crop: Integer percentage setting the total margin used around the
    crop box.
    random_scale: Integer percentage of how much to vary the scale by.
    random_brightness: Integer range to randomly multiply the pixel values by.
    graph.

  Returns:
    The jpeg input layer and the distorted result tensor.
  """

  jpeg_data = tf.placeholder(tf.string, name='DistortJPGInput')
  decoded_image = tf.image.decode_jpeg(jpeg_data, channels=MODEL_INPUT_DEPTH)
  decoded_image_as_float = tf.cast(decoded_image, dtype=tf.float32)
  decoded_image_4d = tf.expand_dims(decoded_image_as_float, 0)
  margin_scale = 1.0 + (random_crop / 100.0)
  resize_scale = 1.0 + (random_scale / 100.0)
  margin_scale_value = tf.constant(margin_scale)
  resize_scale_value = tf.random_uniform(tensor_shape.scalar(),
                                         minval=1.0,
                                         maxval=resize_scale)
  scale_value = tf.multiply(margin_scale_value, resize_scale_value)
  precrop_width = tf.multiply(scale_value, MODEL_INPUT_WIDTH)
  precrop_height = tf.multiply(scale_value, MODEL_INPUT_HEIGHT)
  precrop_shape = tf.stack([precrop_height, precrop_width])
  precrop_shape_as_int = tf.cast(precrop_shape, dtype=tf.int32)
  precropped_image = tf.image.resize_bilinear(decoded_image_4d,
                                              precrop_shape_as_int)
  precropped_image_3d = tf.squeeze(precropped_image, squeeze_dims=[0])
  cropped_image = tf.random_crop(precropped_image_3d,
                                 [MODEL_INPUT_HEIGHT, MODEL_INPUT_WIDTH,
                                  MODEL_INPUT_DEPTH])
  if flip_left_right:
    flipped_image = tf.image.random_flip_left_right(cropped_image)
  else:
    flipped_image = cropped_image
  brightness_min = 1.0 - (random_brightness / 100.0)
  brightness_max = 1.0 + (random_brightness / 100.0)
  brightness_value = tf.random_uniform(tensor_shape.scalar(),
                                       minval=brightness_min,
                                       maxval=brightness_max)
  brightened_image = tf.multiply(flipped_image, brightness_value)
  distort_result = tf.expand_dims(brightened_image, 0, name='DistortResult')
  return jpeg_data, distort_result


def variable_summaries(var, name):
  """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
  with tf.name_scope('summaries'):
    mean = tf.reduce_mean(var)
    tf.summary.scalar('mean/' + name, mean)
    with tf.name_scope('stddev'):
      stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
    tf.summary.scalar('stddev/' + name, stddev)
    tf.summary.scalar('max/' + name, tf.reduce_max(var))
    tf.summary.scalar('min/' + name, tf.reduce_min(var))
    tf.summary.histogram(name, var)


def add_final_training_ops(class_count, final_tensor_name, bottleneck_tensor):
  """Adds a new softmax and fully-connected layer for training.

  We need to retrain the top layer to identify our new classes, so this function
  adds the right operations to the graph, along with some variables to hold the
  weights, and then sets up all the gradients for the backward pass.

  The set up for the softmax and fully-connected layers is based on:
  https://tensorflow.org/versions/master/tutorials/mnist/beginners/index.html

  Args:
    class_count: Integer of how many categories of things we're trying to
    recognize.
    final_tensor_name: Name string for the new final node that produces results.
    bottleneck_tensor: The output of the main CNN graph.

  Returns:
    The tensors for the training and cross entropy results, and tensors for the
    bottleneck input and ground truth input.
  """
  with tf.name_scope('input'):
    bottleneck_input = tf.placeholder_with_default(
        bottleneck_tensor, shape=[None, BOTTLENECK_TENSOR_SIZE],
        name='BottleneckInputPlaceholder')

    ground_truth_input = tf.placeholder(tf.float32,
                                        [None, class_count],
                                        name='GroundTruthInput')

  # Organizing the following ops as `final_training_ops` so they're easier
  # to see in TensorBoard
  layer_name = 'final_training_ops'
  with tf.name_scope(layer_name):
    with tf.name_scope('weights'):
      layer_weights = tf.Variable(tf.truncated_normal([BOTTLENECK_TENSOR_SIZE, class_count], stddev=0.001), name='final_weights')
      variable_summaries(layer_weights, layer_name + '/weights')
    with tf.name_scope('biases'):
      layer_biases = tf.Variable(tf.zeros([class_count]), name='final_biases')
      variable_summaries(layer_biases, layer_name + '/biases')
    with tf.name_scope('Wx_plus_b'):
      logits = tf.matmul(bottleneck_input, layer_weights) + layer_biases
      tf.summary.histogram(layer_name + '/pre_activations', logits)

  final_tensor = tf.nn.sigmoid(logits, name=final_tensor_name)
  tf.summary.histogram(final_tensor_name + '/activations', final_tensor)

  with tf.name_scope('cross_entropy'):
    cross_entropy = tf.nn.sigmoid_cross_entropy_with_logits(
      labels=ground_truth_input,logits=logits)
    with tf.name_scope('total'):
      cross_entropy_mean = tf.reduce_mean(cross_entropy)
    tf.summary.scalar('cross entropy', cross_entropy_mean)

  with tf.name_scope('train'):
    train_step = tf.train.GradientDescentOptimizer(FLAGS.learning_rate).minimize(
        cross_entropy_mean)

  return (train_step, cross_entropy_mean, bottleneck_input, ground_truth_input,
          final_tensor)


def add_evaluation_step(result_tensor, ground_truth_tensor):
  """Inserts the operations we need to evaluate the accuracy of our results.

  Args:
    result_tensor: The new final node that produces results.
    ground_truth_tensor: The node we feed ground truth data
    into.

  Returns:
    Nothing.
  """
  with tf.name_scope('accuracy'):
    with tf.name_scope('correct_prediction'):
      # tf.argmax(result_tensor, 1) = return index of maximal value (= 1 in a 1-of-N encoding vector) in each row (axis = 1)
      # But we have more ones (indicating multiple labels) in one row of result_tensor due to the multi-label classification
      # correct_prediction = tf.equal(tf.argmax(result_tensor, 1), \
      #   tf.argmax(ground_truth_tensor, 1))

      # ground_truth is not a binary tensor, it contains the probabilities of each label = we need to tf.round() it
      # to acquire a binary tensor allowing comparison by tf.equal()
      # See: http://stackoverflow.com/questions/39219414/in-tensorflow-how-can-i-get-nonzero-values-and-their-indices-from-a-tensor-with

      correct_prediction = tf.equal(tf.round(result_tensor), ground_truth_tensor)
    with tf.name_scope('accuracy'):
      # Mean accuracy over all labels:
      # http://stackoverflow.com/questions/37746670/tensorflow-multi-label-accuracy-calculation
      evaluation_step = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    tf.summary.scalar('accuracy', evaluation_step)
  return evaluation_step


def main(_):
  # Setup the directory we'll write summaries to for TensorBoard
  if tf.gfile.Exists(FLAGS.summaries_dir):
    tf.gfile.DeleteRecursively(FLAGS.summaries_dir)
  tf.gfile.MakeDirs(FLAGS.summaries_dir)

  # Set up the pre-trained graph.
  maybe_download_and_extract()
  graph, bottleneck_tensor, jpeg_data_tensor, resized_image_tensor = (
      create_inception_graph())

  # Look at the folder structure, and create lists of all the images.
  image_lists = create_image_lists(FLAGS.image_dir, FLAGS.testing_percentage,
                                   FLAGS.validation_percentage)

  if len(image_lists.keys()) == 0:
     
      print('Folder containing training images has not been found inside {} directory. \n'
            'Put all the training images into '
            'one folder inside {} directory and delete everything else inside the {} directory.'
            .format(FLAGS.image_dir, FLAGS.image_dir, FLAGS.image_dir))
      return -1

  if len(image_lists.keys()) > 1:
      print('More than one folder found inside {} directory. \n'
            'In order to prevent validation issues, put all the training images into '
            'one folder inside {} directory and delete everything else inside the {} directory.'
            .format(FLAGS.image_dir, FLAGS.image_dir, FLAGS.image_dir))
      return -1

  if not os.path.isfile(ALL_LABELS_FILE):
      print('File {} containing all possible labels (= classes) does not exist.\n'
            'Create it in project root and put each possible label on new line, '
            'it is exactly the same as creating an image_label file for image '
            'that is in all the possible classes.'.format(ALL_LABELS_FILE))
      return -1

  with open(ALL_LABELS_FILE) as f:
      labels = f.read().splitlines()
  class_count = len(labels)

  if class_count == 0:
    print('No valid labels inside file {} that should contain all possible labels (= classes).'.format(ALL_LABELS_FILE))
    return -1
  if class_count == 1:
    print('Only one valid label found inside {} - multiple classes are needed for classification.'.format(ALL_LABELS_FILE))
    return -1

  # See if the command-line flags mean we're applying any distortions.
  do_distort_images = should_distort_images(
      FLAGS.flip_left_right, FLAGS.random_crop, FLAGS.random_scale,
      FLAGS.random_brightness)
  sess = tf.Session()

  if do_distort_images:
    # We will be applying distortions, so setup the operations we'll need.
    distorted_jpeg_data_tensor, distorted_image_tensor = add_input_distortions(
        FLAGS.flip_left_right, FLAGS.random_crop, FLAGS.random_scale,
        FLAGS.random_brightness)
  else:
    # We'll make sure we've calculated the 'bottleneck' image summaries and
    # cached them on disk.
    cache_bottlenecks(sess, image_lists, FLAGS.image_dir, FLAGS.bottleneck_dir,
                      jpeg_data_tensor, bottleneck_tensor)

  # Add the new layer that we'll be training.
  (train_step, cross_entropy, bottleneck_input, ground_truth_input,
   final_tensor) = add_final_training_ops(class_count,
                                          FLAGS.final_tensor_name,
                                          bottleneck_tensor)

  # Create the operations we need to evaluate the accuracy of our new layer.
  evaluation_step = add_evaluation_step(final_tensor, ground_truth_input)

  # Merge all the summaries and write them out to /tmp/retrain_logs (by default)
  merged = tf.summary.merge_all()
  train_writer = tf.summary.FileWriter(FLAGS.summaries_dir + '/train',
                                        sess.graph)
  validation_writer = tf.summary.FileWriter(FLAGS.summaries_dir + '/validation')

  # Set up all our weights to their initial default values.
  init = tf.global_variables_initializer()
  sess.run(init)

  # Run the training for as many cycles as requested on the command line.
  for i in range(FLAGS.how_many_training_steps):
    # Get a batch of input bottleneck values, either calculated fresh every time
    # with distortions applied, or from the cache stored on disk.
    if do_distort_images:
      train_bottlenecks, train_ground_truth = get_random_distorted_bottlenecks(
          sess, image_lists, FLAGS.train_batch_size, 'training',
          FLAGS.image_dir, distorted_jpeg_data_tensor,
          distorted_image_tensor, resized_image_tensor, bottleneck_tensor)
    else:
      train_bottlenecks, train_ground_truth = get_random_cached_bottlenecks(
          sess, image_lists, FLAGS.train_batch_size, 'training',
          FLAGS.bottleneck_dir, FLAGS.image_dir, jpeg_data_tensor,
          bottleneck_tensor, labels)
    # Feed the bottlenecks and ground truth into the graph, and run a training
    # step. Capture training summaries for TensorBoard with the `merged` op.
    train_summary, _ = sess.run([merged, train_step],
             feed_dict={bottleneck_input: train_bottlenecks,
                        ground_truth_input: train_ground_truth})
    train_writer.add_summary(train_summary, i)

    # Every so often, print out how well the graph is training.
    is_last_step = (i + 1 == FLAGS.how_many_training_steps)
    if (i % FLAGS.eval_step_interval) == 0 or is_last_step:
      train_accuracy, cross_entropy_value = sess.run(
          [evaluation_step, cross_entropy],
          feed_dict={bottleneck_input: train_bottlenecks,
                     ground_truth_input: train_ground_truth})
      print('%s: Step %d: Train accuracy = %.1f%%' % (datetime.now(), i,
                                                      train_accuracy * 100))
      print('%s: Step %d: Cross entropy = %f' % (datetime.now(), i,
                                                 cross_entropy_value))
      validation_bottlenecks, validation_ground_truth = (
          get_random_cached_bottlenecks(
              sess, image_lists, FLAGS.validation_batch_size, 'validation',
              FLAGS.bottleneck_dir, FLAGS.image_dir, jpeg_data_tensor,
              bottleneck_tensor, labels))
      # Run a validation step and capture training summaries for TensorBoard
      # with the `merged` op.
      validation_summary, validation_accuracy = sess.run(
          [merged, evaluation_step],
          feed_dict={bottleneck_input: validation_bottlenecks,
                     ground_truth_input: validation_ground_truth})
      validation_writer.add_summary(validation_summary, i)
      print('%s: Step %d: Validation accuracy = %.1f%%' %
            (datetime.now(), i, validation_accuracy * 100))

  # We've completed all our training, so run a final test evaluation on
  # some new images we haven't used before.
  test_bottlenecks, test_ground_truth = get_random_cached_bottlenecks(
      sess, image_lists, FLAGS.test_batch_size, 'testing',
      FLAGS.bottleneck_dir, FLAGS.image_dir, jpeg_data_tensor,
      bottleneck_tensor, labels)
  test_accuracy = sess.run(
      evaluation_step,
      feed_dict={bottleneck_input: test_bottlenecks,
                 ground_truth_input: test_ground_truth})
  print('Final test accuracy = %.1f%%' % (test_accuracy * 100))

  # Write out the trained graph and labels with the weights stored as constants.
  output_graph_def = graph_util.convert_variables_to_constants(
      sess, graph.as_graph_def(), [FLAGS.final_tensor_name])
  with gfile.FastGFile(FLAGS.output_graph, 'wb') as f:
    f.write(output_graph_def.SerializeToString())
  with gfile.FastGFile(FLAGS.output_labels, 'w') as f:
    f.write('\n'.join(image_lists.keys()) + '\n')


if __name__ == '__main__':
  tf.app.run()
# Out:
# >> Downloading inception-2015-12-05.tgz 100.0%
# Successfully downloaded inception-2015-12-05.tgz 88931400 bytes.
# Looking for images in '11'
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat108.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat134.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat120.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog132.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C207.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C213.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat60.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat48.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog287.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C52.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog38.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog293.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C46.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat242.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog10.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat256.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C91.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog244.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C159.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog250.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C171.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat281.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat295.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C165.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog5.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C1.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog4.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C164.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat294.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat280.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog279.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C170.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog251.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C84.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C158.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog245.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C90.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat257.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat243.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog11.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C47.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog292.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C53.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog286.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat49.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat75.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat61.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C212.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C206.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog127.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog133.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat121.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat135.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat109.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat137.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog125.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C238.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog131.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C210.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog119.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C204.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat88.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat77.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog290.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat269.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C45.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C199.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog284.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C51.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat255.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog13.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat241.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C86.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C92.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog247.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat296.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C172.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat282.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C3.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog6.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C2.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat283.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C173.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat297.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog246.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C93.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog252.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C87.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog12.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat240.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C78.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat254.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C50.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog285.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C198.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat268.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog291.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat62.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat76.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat89.jpg.txt
# 100 bottleneck files created.
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C205.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog118.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog130.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C239.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog124.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat136.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat122.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat126.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat132.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C215.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog108.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C201.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog120.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C229.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog134.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat99.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat66.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat250.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat244.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C68.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog16.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C40.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C188.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat278.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C54.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat293.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C163.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C177.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat287.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C83.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog256.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog242.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog2.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C7.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog243.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C96.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog257.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C82.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat286.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C176.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C162.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C55.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog280.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat279.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C189.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C41.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog294.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C69.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat245.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog17.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat251.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat67.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat73.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat98.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog135.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C228.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog121.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C200.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog109.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C214.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat133.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat127.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat131.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat125.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat119.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C202.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C216.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog137.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog123.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat59.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat65.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat247.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat253.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog29.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog282.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C57.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog296.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C43.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C174.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat290.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C160.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C94.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog241.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C148.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C80.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog255.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C5.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C4.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog1.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog254.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C81.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C149.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog240.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C161.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog268.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat291.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat285.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C175.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C42.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog297.jpg.txt
# 200 bottleneck files created.
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C56.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat252.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog14.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat70.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat64.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat58.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog122.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C217.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C203.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat118.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat124.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat130.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog192.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat157.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat143.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog151.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C258.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog145.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C264.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat194.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog179.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat180.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C270.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat17.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat209.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C25.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog73.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat1.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat221.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat235.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C19.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog67.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog227.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog233.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog98.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C112.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C106.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C107.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C113.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog232.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog99.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog226.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C18.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat234.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog66.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog72.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat220.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C24.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat208.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C30.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat16.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat181.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog178.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C265.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog144.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C259.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog150.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat142.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat156.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog187.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog193.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog185.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog191.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat168.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat140.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat154.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog146.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog152.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C273.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C267.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat197.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat14.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat28.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog58.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C26.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C32.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog64.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat236.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat2.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat222.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog70.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog230.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C139.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog224.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C105.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog218.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C111.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C110.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog219.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C104.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C138.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog231.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat223.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat3.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog71.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog65.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat237.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C33.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog59.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C27.jpg.txt
# 300 bottleneck files created.
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat29.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat15.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C266.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat182.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog153.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog147.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat155.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat141.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat169.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog190.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog184.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat145.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat151.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat179.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog180.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C289.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog194.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat186.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C262.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat192.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog143.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog157.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat39.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat11.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat233.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog61.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat7.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat227.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog49.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C37.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C100.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog209.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog235.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C128.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog221.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog220.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C129.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog234.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog208.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C101.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog48.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C36.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C22.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat232.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat10.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog156.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog142.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat193.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C263.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C277.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat187.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog195.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C288.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog181.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat178.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat150.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat144.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat152.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat146.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog197.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C261.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat191.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog168.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat185.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog154.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C249.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog140.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat12.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat4.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat224.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog76.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog62.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat230.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat218.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C20.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C117.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C103.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog89.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog236.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog237.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog223.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog88.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C102.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C116.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C21.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C35.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat219.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog63.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat231.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat225.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat5.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog77.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat13.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog141.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C248.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog155.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C274.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat184.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog169.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat190.jpg.txt
# 400 bottleneck files created.
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C260.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog196.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat153.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C286.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat176.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat162.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C292.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C279.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog170.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat189.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C245.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog158.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat22.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat36.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C10.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat8.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog52.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat200.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat214.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C38.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog46.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog212.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog91.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C133.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C127.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog85.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C126.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog84.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog90.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog213.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog207.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C39.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog47.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog53.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat201.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat9.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat229.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C11.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat37.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat23.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog159.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C250.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C244.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog165.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat188.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog171.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C293.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat163.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat177.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C287.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat149.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog198.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat161.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C291.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C285.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat175.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog167.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog173.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C252.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat35.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat21.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C13.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog45.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat217.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat203.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog51.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C118.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog211.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog205.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog86.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C130.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog239.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog92.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C131.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog93.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog87.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C125.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog210.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C119.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat202.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog50.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog44.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat216.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C12.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog78.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat34.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C253.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog172.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog166.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat174.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C284.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C290.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat160.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog199.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat164.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C294.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C280.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat170.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog189.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat158.jpg.txt
# 500 bottleneck files created.
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C257.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C243.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog162.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog176.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat18.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat30.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat212.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog40.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog54.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat206.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog68.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C16.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog228.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C121.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog83.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog97.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog214.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog200.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C109.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C108.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog201.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog215.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C134.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C120.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog229.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog82.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog69.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C17.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog55.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat207.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat213.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog41.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat25.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat31.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat19.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog177.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog163.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C242.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C256.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat159.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog188.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat171.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C281.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat165.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat167.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C297.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog149.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C240.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C254.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog175.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat198.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog161.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C268.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat27.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat33.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat205.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog57.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog43.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat211.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat239.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C136.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog94.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog80.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C122.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog203.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog217.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog216.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog202.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog81.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C123.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog95.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C14.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat238.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog42.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat210.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C28.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat204.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog56.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat32.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat26.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C269.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat199.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog174.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C241.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C296.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat166.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat172.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C282.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat129.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat101.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog113.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog107.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C226.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C232.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat82.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat96.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat41.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat55.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat69.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C73.jpg.txt
# 600 bottleneck files created.
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog19.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C67.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat263.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog31.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog25.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat277.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C187.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog265.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog271.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat288.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C178.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog259.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C150.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C144.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C98.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C9.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C8.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C145.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C151.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog258.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C179.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat289.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog270.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog264.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog24.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C186.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat276.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat262.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C192.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog18.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C66.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C72.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat68.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat54.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat40.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat97.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat83.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C233.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C227.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog106.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat100.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat114.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat128.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat102.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog104.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog110.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C219.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C225.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat95.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat81.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat300.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat56.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat42.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat248.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C64.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C70.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat274.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C58.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog26.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog32.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C190.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat260.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog272.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C147.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C153.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C152.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C146.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog267.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog273.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog33.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat261.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog298.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C191.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C185.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C59.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat275.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog27.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C71.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C65.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat249.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat43.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat57.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat80.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C224.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C230.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog139.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C218.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog111.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog105.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat117.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat103.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat107.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat113.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C234.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C220.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog129.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C208.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog101.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog115.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat90.jpg.txt
# 700 bottleneck files created.
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat84.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat53.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat47.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog23.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat271.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog288.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C181.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat265.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C49.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C61.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat259.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C75.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C142.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C156.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog277.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog263.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog262.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C157.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C143.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C48.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat264.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C194.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog36.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C180.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog289.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat270.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat46.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat52.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat91.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog114.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog100.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C209.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog128.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C235.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat112.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat106.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat110.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat104.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C223.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C237.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog116.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog102.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat87.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat93.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat78.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog300.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat50.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog34.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat266.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C182.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog20.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C62.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C155.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C141.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog248.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/D&C169.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Cat299.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog260.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog274.jpg.txt
# Creating bottleneck at /tmp/Final/bottleneck/11/Dog9.jpg.txt
# ...
# 2018-04-29 14:28:17.164931: Step 1200: Validation accuracy = 100.0%
# 2018-04-29 14:28:17.338173: Step 1210: Train accuracy = 96.9%
# 2018-04-29 14:28:17.338291: Step 1210: Cross entropy = 0.097539
# 2018-04-29 14:28:17.356247: Step 1210: Validation accuracy = 90.6%
# 2018-04-29 14:28:17.529293: Step 1220: Train accuracy = 100.0%
# 2018-04-29 14:28:17.529398: Step 1220: Cross entropy = 0.073131
# 2018-04-29 14:28:17.547026: Step 1220: Validation accuracy = 96.9%
# 2018-04-29 14:28:17.722986: Step 1230: Train accuracy = 100.0%
# 2018-04-29 14:28:17.723117: Step 1230: Cross entropy = 0.063709
# 2018-04-29 14:28:17.742173: Step 1230: Validation accuracy = 96.9%
# 2018-04-29 14:28:17.916588: Step 1240: Train accuracy = 96.9%
# 2018-04-29 14:28:17.916701: Step 1240: Cross entropy = 0.086027
# 2018-04-29 14:28:17.934404: Step 1240: Validation accuracy = 96.9%
# 2018-04-29 14:28:18.106952: Step 1250: Train accuracy = 100.0%
# 2018-04-29 14:28:18.107078: Step 1250: Cross entropy = 0.056986
# 2018-04-29 14:28:18.125114: Step 1250: Validation accuracy = 96.9%
# 2018-04-29 14:28:18.300090: Step 1260: Train accuracy = 100.0%
# 2018-04-29 14:28:18.300195: Step 1260: Cross entropy = 0.101634
# 2018-04-29 14:28:18.318565: Step 1260: Validation accuracy = 96.9%
# 2018-04-29 14:28:18.484233: Step 1270: Train accuracy = 100.0%
# 2018-04-29 14:28:18.484383: Step 1270: Cross entropy = 0.057538
# 2018-04-29 14:28:18.501142: Step 1270: Validation accuracy = 90.6%
# 2018-04-29 14:28:18.672731: Step 1280: Train accuracy = 100.0%
# 2018-04-29 14:28:18.672852: Step 1280: Cross entropy = 0.072377
# 2018-04-29 14:28:18.691478: Step 1280: Validation accuracy = 100.0%
# 2018-04-29 14:28:18.863979: Step 1290: Train accuracy = 100.0%
# 2018-04-29 14:28:18.864077: Step 1290: Cross entropy = 0.073483
# 2018-04-29 14:28:18.882497: Step 1290: Validation accuracy = 93.8%
# 2018-04-29 14:28:19.059331: Step 1300: Train accuracy = 100.0%
# 2018-04-29 14:28:19.059444: Step 1300: Cross entropy = 0.064698
# 2018-04-29 14:28:19.076633: Step 1300: Validation accuracy = 90.6%
# 2018-04-29 14:28:19.248404: Step 1310: Train accuracy = 96.9%
# 2018-04-29 14:28:19.248511: Step 1310: Cross entropy = 0.081004
# 2018-04-29 14:28:19.266081: Step 1310: Validation accuracy = 100.0%
# 2018-04-29 14:28:19.438083: Step 1320: Train accuracy = 96.9%
# 2018-04-29 14:28:19.438194: Step 1320: Cross entropy = 0.123690
# 2018-04-29 14:28:19.456601: Step 1320: Validation accuracy = 100.0%
# 2018-04-29 14:28:19.631701: Step 1330: Train accuracy = 96.9%
# 2018-04-29 14:28:19.631812: Step 1330: Cross entropy = 0.116433
# 2018-04-29 14:28:19.649216: Step 1330: Validation accuracy = 93.8%
# 2018-04-29 14:28:19.823810: Step 1340: Train accuracy = 100.0%
# 2018-04-29 14:28:19.823936: Step 1340: Cross entropy = 0.060418
# 2018-04-29 14:28:19.841375: Step 1340: Validation accuracy = 93.8%
# 2018-04-29 14:28:20.014497: Step 1350: Train accuracy = 96.9%
# 2018-04-29 14:28:20.014608: Step 1350: Cross entropy = 0.069444
# 2018-04-29 14:28:20.034044: Step 1350: Validation accuracy = 90.6%
# 2018-04-29 14:28:20.207752: Step 1360: Train accuracy = 100.0%
# 2018-04-29 14:28:20.207859: Step 1360: Cross entropy = 0.097196
# 2018-04-29 14:28:20.225100: Step 1360: Validation accuracy = 96.9%
# 2018-04-29 14:28:20.398544: Step 1370: Train accuracy = 96.9%
# 2018-04-29 14:28:20.398664: Step 1370: Cross entropy = 0.088462
# 2018-04-29 14:28:20.416310: Step 1370: Validation accuracy = 100.0%
# 2018-04-29 14:28:20.579210: Step 1380: Train accuracy = 100.0%
# 2018-04-29 14:28:20.579319: Step 1380: Cross entropy = 0.071502
# 2018-04-29 14:28:20.597561: Step 1380: Validation accuracy = 100.0%
# 2018-04-29 14:28:20.769457: Step 1390: Train accuracy = 100.0%
# 2018-04-29 14:28:20.769581: Step 1390: Cross entropy = 0.055860
# 2018-04-29 14:28:20.787868: Step 1390: Validation accuracy = 90.6%
# 2018-04-29 14:28:20.963221: Step 1400: Train accuracy = 100.0%
# 2018-04-29 14:28:20.963354: Step 1400: Cross entropy = 0.063118
# 2018-04-29 14:28:20.983968: Step 1400: Validation accuracy = 93.8%
# 2018-04-29 14:28:21.158501: Step 1410: Train accuracy = 100.0%
# 2018-04-29 14:28:21.158604: Step 1410: Cross entropy = 0.087811
# 2018-04-29 14:28:21.176612: Step 1410: Validation accuracy = 96.9%
# 2018-04-29 14:28:21.355571: Step 1420: Train accuracy = 96.9%
# 2018-04-29 14:28:21.355692: Step 1420: Cross entropy = 0.101301
# 2018-04-29 14:28:21.373565: Step 1420: Validation accuracy = 90.6%
# 2018-04-29 14:28:21.552326: Step 1430: Train accuracy = 100.0%
# 2018-04-29 14:28:21.552430: Step 1430: Cross entropy = 0.050097
# 2018-04-29 14:28:21.572120: Step 1430: Validation accuracy = 93.8%
# 2018-04-29 14:28:21.748024: Step 1440: Train accuracy = 100.0%
# 2018-04-29 14:28:21.748134: Step 1440: Cross entropy = 0.054637
# 2018-04-29 14:28:21.765640: Step 1440: Validation accuracy = 100.0%
# 2018-04-29 14:28:21.941470: Step 1450: Train accuracy = 96.9%
# 2018-04-29 14:28:21.941591: Step 1450: Cross entropy = 0.081400
# 2018-04-29 14:28:21.959694: Step 1450: Validation accuracy = 96.9%
# 2018-04-29 14:28:22.134918: Step 1460: Train accuracy = 93.8%
# 2018-04-29 14:28:22.135033: Step 1460: Cross entropy = 0.123089
# 2018-04-29 14:28:22.154195: Step 1460: Validation accuracy = 93.8%
# 2018-04-29 14:28:22.327579: Step 1470: Train accuracy = 100.0%
# 2018-04-29 14:28:22.327688: Step 1470: Cross entropy = 0.070935
# 2018-04-29 14:28:22.345142: Step 1470: Validation accuracy = 90.6%
# 2018-04-29 14:28:22.513125: Step 1480: Train accuracy = 96.9%
# 2018-04-29 14:28:22.513250: Step 1480: Cross entropy = 0.160367
# 2018-04-29 14:28:22.531104: Step 1480: Validation accuracy = 100.0%
# 2018-04-29 14:28:22.700842: Step 1490: Train accuracy = 100.0%
# 2018-04-29 14:28:22.700950: Step 1490: Cross entropy = 0.048619
# 2018-04-29 14:28:22.718225: Step 1490: Validation accuracy = 100.0%
# 2018-04-29 14:28:22.890188: Step 1500: Train accuracy = 100.0%
# 2018-04-29 14:28:22.890288: Step 1500: Cross entropy = 0.086906
# 2018-04-29 14:28:22.907830: Step 1500: Validation accuracy = 93.8%
# 2018-04-29 14:28:23.083456: Step 1510: Train accuracy = 96.9%
# 2018-04-29 14:28:23.083586: Step 1510: Cross entropy = 0.086164
# 2018-04-29 14:28:23.102979: Step 1510: Validation accuracy = 96.9%
# 2018-04-29 14:28:23.277046: Step 1520: Train accuracy = 96.9%
# 2018-04-29 14:28:23.277155: Step 1520: Cross entropy = 0.097967
# 2018-04-29 14:28:23.296376: Step 1520: Validation accuracy = 100.0%
# 2018-04-29 14:28:23.475440: Step 1530: Train accuracy = 96.9%
# 2018-04-29 14:28:23.475560: Step 1530: Cross entropy = 0.089597
# 2018-04-29 14:28:23.494401: Step 1530: Validation accuracy = 93.8%
# 2018-04-29 14:28:23.673568: Step 1540: Train accuracy = 100.0%
# 2018-04-29 14:28:23.673689: Step 1540: Cross entropy = 0.077662
# 2018-04-29 14:28:23.691188: Step 1540: Validation accuracy = 96.9%
# 2018-04-29 14:28:23.867899: Step 1550: Train accuracy = 96.9%
# 2018-04-29 14:28:23.868004: Step 1550: Cross entropy = 0.101188
# 2018-04-29 14:28:23.886995: Step 1550: Validation accuracy = 96.9%
# 2018-04-29 14:28:24.060966: Step 1560: Train accuracy = 100.0%
# 2018-04-29 14:28:24.061093: Step 1560: Cross entropy = 0.057723
# 2018-04-29 14:28:24.079752: Step 1560: Validation accuracy = 100.0%
# 2018-04-29 14:28:24.255235: Step 1570: Train accuracy = 100.0%
# 2018-04-29 14:28:24.255366: Step 1570: Cross entropy = 0.063080
# 2018-04-29 14:28:24.273761: Step 1570: Validation accuracy = 100.0%
# 2018-04-29 14:28:24.445106: Step 1580: Train accuracy = 100.0%
# 2018-04-29 14:28:24.445238: Step 1580: Cross entropy = 0.090257
# 2018-04-29 14:28:24.463577: Step 1580: Validation accuracy = 93.8%
# 2018-04-29 14:28:24.633784: Step 1590: Train accuracy = 93.8%
# 2018-04-29 14:28:24.633896: Step 1590: Cross entropy = 0.108370
# 2018-04-29 14:28:24.650882: Step 1590: Validation accuracy = 96.9%
# 2018-04-29 14:28:24.825000: Step 1600: Train accuracy = 100.0%
# 2018-04-29 14:28:24.825125: Step 1600: Cross entropy = 0.037751
# 2018-04-29 14:28:24.842888: Step 1600: Validation accuracy = 93.8%
# 2018-04-29 14:28:25.017172: Step 1610: Train accuracy = 100.0%
# 2018-04-29 14:28:25.017282: Step 1610: Cross entropy = 0.047543
# 2018-04-29 14:28:25.036853: Step 1610: Validation accuracy = 96.9%
# 2018-04-29 14:28:25.209951: Step 1620: Train accuracy = 100.0%
# 2018-04-29 14:28:25.210069: Step 1620: Cross entropy = 0.097460
# 2018-04-29 14:28:25.229518: Step 1620: Validation accuracy = 100.0%
# 2018-04-29 14:28:25.414934: Step 1630: Train accuracy = 96.9%
# 2018-04-29 14:28:25.415060: Step 1630: Cross entropy = 0.078674
# 2018-04-29 14:28:25.433894: Step 1630: Validation accuracy = 100.0%
# 2018-04-29 14:28:25.607060: Step 1640: Train accuracy = 96.9%
# 2018-04-29 14:28:25.607162: Step 1640: Cross entropy = 0.068279
# 2018-04-29 14:28:25.625728: Step 1640: Validation accuracy = 93.8%
# 2018-04-29 14:28:25.800860: Step 1650: Train accuracy = 96.9%
# 2018-04-29 14:28:25.800983: Step 1650: Cross entropy = 0.065508
# 2018-04-29 14:28:25.819520: Step 1650: Validation accuracy = 96.9%
# 2018-04-29 14:28:25.992403: Step 1660: Train accuracy = 100.0%
# 2018-04-29 14:28:25.992522: Step 1660: Cross entropy = 0.049136
# 2018-04-29 14:28:26.009654: Step 1660: Validation accuracy = 100.0%
# 2018-04-29 14:28:26.179728: Step 1670: Train accuracy = 96.9%
# 2018-04-29 14:28:26.179853: Step 1670: Cross entropy = 0.141190
# 2018-04-29 14:28:26.198618: Step 1670: Validation accuracy = 93.8%
# 2018-04-29 14:28:26.372542: Step 1680: Train accuracy = 100.0%
# 2018-04-29 14:28:26.372668: Step 1680: Cross entropy = 0.047281
# 2018-04-29 14:28:26.389487: Step 1680: Validation accuracy = 96.9%
# 2018-04-29 14:28:26.559268: Step 1690: Train accuracy = 93.8%
# 2018-04-29 14:28:26.559392: Step 1690: Cross entropy = 0.129421
# 2018-04-29 14:28:26.576899: Step 1690: Validation accuracy = 100.0%
# 2018-04-29 14:28:26.746573: Step 1700: Train accuracy = 100.0%
# 2018-04-29 14:28:26.746689: Step 1700: Cross entropy = 0.049290
# 2018-04-29 14:28:26.765461: Step 1700: Validation accuracy = 96.9%
# 2018-04-29 14:28:26.944617: Step 1710: Train accuracy = 100.0%
# 2018-04-29 14:28:26.944728: Step 1710: Cross entropy = 0.045706
# 2018-04-29 14:28:26.962013: Step 1710: Validation accuracy = 96.9%
# 2018-04-29 14:28:27.138163: Step 1720: Train accuracy = 96.9%
# 2018-04-29 14:28:27.138264: Step 1720: Cross entropy = 0.112173
# 2018-04-29 14:28:27.156020: Step 1720: Validation accuracy = 93.8%
# 2018-04-29 14:28:27.328244: Step 1730: Train accuracy = 96.9%
# 2018-04-29 14:28:27.328357: Step 1730: Cross entropy = 0.144476
# 2018-04-29 14:28:27.347041: Step 1730: Validation accuracy = 96.9%
# 2018-04-29 14:28:27.520398: Step 1740: Train accuracy = 96.9%
# 2018-04-29 14:28:27.520509: Step 1740: Cross entropy = 0.074672
# 2018-04-29 14:28:27.537789: Step 1740: Validation accuracy = 90.6%
# 2018-04-29 14:28:27.713231: Step 1750: Train accuracy = 96.9%
# 2018-04-29 14:28:27.713332: Step 1750: Cross entropy = 0.104269
# 2018-04-29 14:28:27.730522: Step 1750: Validation accuracy = 96.9%
# 2018-04-29 14:28:27.903688: Step 1760: Train accuracy = 96.9%
# 2018-04-29 14:28:27.903797: Step 1760: Cross entropy = 0.052200
# 2018-04-29 14:28:27.922146: Step 1760: Validation accuracy = 93.8%
# 2018-04-29 14:28:28.098971: Step 1770: Train accuracy = 100.0%
# 2018-04-29 14:28:28.099079: Step 1770: Cross entropy = 0.053492
# 2018-04-29 14:28:28.116269: Step 1770: Validation accuracy = 96.9%
# 2018-04-29 14:28:28.292208: Step 1780: Train accuracy = 96.9%
# 2018-04-29 14:28:28.292326: Step 1780: Cross entropy = 0.134323
# 2018-04-29 14:28:28.310405: Step 1780: Validation accuracy = 96.9%
# 2018-04-29 14:28:28.476331: Step 1790: Train accuracy = 100.0%
# 2018-04-29 14:28:28.476460: Step 1790: Cross entropy = 0.032365
# 2018-04-29 14:28:28.493237: Step 1790: Validation accuracy = 100.0%
# 2018-04-29 14:28:28.665336: Step 1800: Train accuracy = 100.0%
# 2018-04-29 14:28:28.665460: Step 1800: Cross entropy = 0.100389
# 2018-04-29 14:28:28.683529: Step 1800: Validation accuracy = 90.6%
# 2018-04-29 14:28:28.866315: Step 1810: Train accuracy = 96.9%
# 2018-04-29 14:28:28.866454: Step 1810: Cross entropy = 0.123574
# 2018-04-29 14:28:28.885093: Step 1810: Validation accuracy = 93.8%
# 2018-04-29 14:28:29.060683: Step 1820: Train accuracy = 96.9%
# 2018-04-29 14:28:29.060794: Step 1820: Cross entropy = 0.121152
# 2018-04-29 14:28:29.079624: Step 1820: Validation accuracy = 93.8%
# 2018-04-29 14:28:29.250714: Step 1830: Train accuracy = 100.0%
# 2018-04-29 14:28:29.250827: Step 1830: Cross entropy = 0.033851
# 2018-04-29 14:28:29.268402: Step 1830: Validation accuracy = 100.0%
# 2018-04-29 14:28:29.442766: Step 1840: Train accuracy = 100.0%
# 2018-04-29 14:28:29.442883: Step 1840: Cross entropy = 0.039846
# 2018-04-29 14:28:29.462677: Step 1840: Validation accuracy = 100.0%
# 2018-04-29 14:28:29.636277: Step 1850: Train accuracy = 96.9%
# 2018-04-29 14:28:29.636403: Step 1850: Cross entropy = 0.109172
# 2018-04-29 14:28:29.656926: Step 1850: Validation accuracy = 96.9%
# 2018-04-29 14:28:29.830897: Step 1860: Train accuracy = 96.9%
# 2018-04-29 14:28:29.831014: Step 1860: Cross entropy = 0.064002
# 2018-04-29 14:28:29.848857: Step 1860: Validation accuracy = 100.0%
# 2018-04-29 14:28:30.022855: Step 1870: Train accuracy = 96.9%
# 2018-04-29 14:28:30.022981: Step 1870: Cross entropy = 0.086459
# 2018-04-29 14:28:30.042503: Step 1870: Validation accuracy = 96.9%
# 2018-04-29 14:28:30.214002: Step 1880: Train accuracy = 100.0%
# 2018-04-29 14:28:30.214115: Step 1880: Cross entropy = 0.051455
# 2018-04-29 14:28:30.233882: Step 1880: Validation accuracy = 93.8%
# 2018-04-29 14:28:30.401971: Step 1890: Train accuracy = 100.0%
# 2018-04-29 14:28:30.402096: Step 1890: Cross entropy = 0.076311
# 2018-04-29 14:28:30.419157: Step 1890: Validation accuracy = 90.6%
# 2018-04-29 14:28:30.588929: Step 1900: Train accuracy = 100.0%
# 2018-04-29 14:28:30.589032: Step 1900: Cross entropy = 0.062820
# 2018-04-29 14:28:30.607886: Step 1900: Validation accuracy = 93.8%
# 2018-04-29 14:28:30.781599: Step 1910: Train accuracy = 100.0%
# 2018-04-29 14:28:30.781718: Step 1910: Cross entropy = 0.045469
# 2018-04-29 14:28:30.800743: Step 1910: Validation accuracy = 90.6%
# 2018-04-29 14:28:30.973504: Step 1920: Train accuracy = 100.0%
# 2018-04-29 14:28:30.973617: Step 1920: Cross entropy = 0.037062
# 2018-04-29 14:28:30.991259: Step 1920: Validation accuracy = 93.8%
# 2018-04-29 14:28:31.167550: Step 1930: Train accuracy = 100.0%
# 2018-04-29 14:28:31.167653: Step 1930: Cross entropy = 0.034110
# 2018-04-29 14:28:31.185112: Step 1930: Validation accuracy = 100.0%
# 2018-04-29 14:28:31.361123: Step 1940: Train accuracy = 96.9%
# 2018-04-29 14:28:31.361225: Step 1940: Cross entropy = 0.110166
# 2018-04-29 14:28:31.380261: Step 1940: Validation accuracy = 100.0%
# 2018-04-29 14:28:31.555487: Step 1950: Train accuracy = 100.0%
# 2018-04-29 14:28:31.555597: Step 1950: Cross entropy = 0.050192
# 2018-04-29 14:28:31.573179: Step 1950: Validation accuracy = 96.9%
# 2018-04-29 14:28:31.751847: Step 1960: Train accuracy = 100.0%
# 2018-04-29 14:28:31.751961: Step 1960: Cross entropy = 0.033916
# 2018-04-29 14:28:31.769980: Step 1960: Validation accuracy = 100.0%
# 2018-04-29 14:28:31.942582: Step 1970: Train accuracy = 100.0%
# 2018-04-29 14:28:31.942735: Step 1970: Cross entropy = 0.042947
# 2018-04-29 14:28:31.961477: Step 1970: Validation accuracy = 93.8%
# 2018-04-29 14:28:32.137682: Step 1980: Train accuracy = 100.0%
# 2018-04-29 14:28:32.137791: Step 1980: Cross entropy = 0.053235
# 2018-04-29 14:28:32.155863: Step 1980: Validation accuracy = 96.9%
# 2018-04-29 14:28:32.336601: Step 1990: Train accuracy = 100.0%
# 2018-04-29 14:28:32.336950: Step 1990: Cross entropy = 0.034045
# 2018-04-29 14:28:32.354519: Step 1990: Validation accuracy = 96.9%
# 2018-04-29 14:28:32.518550: Step 1999: Train accuracy = 96.9%
# 2018-04-29 14:28:32.518664: Step 1999: Cross entropy = 0.104544
# 2018-04-29 14:28:32.536405: Step 1999: Validation accuracy = 93.8%
# Final test accuracy = 84.4%
# INFO:tensorflow:Froze 2 variables.
# Converted 2 variables to const ops.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /Users/liutianchen/anaconda3/envs/tf_py3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
